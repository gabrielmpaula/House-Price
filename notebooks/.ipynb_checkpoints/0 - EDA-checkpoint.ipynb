# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd
import numpy as np
import os

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
print(os.listdir('../data/'))
# Out:
# ['data_description.txt', 'sample_submission.csv', 'test.csv', 'train.csv']

# %% [markdown]
# ## Checking data_description.txt

# %%
# !cat {../data/data_description.txt}
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Loading Data

# %%
DATA_PATH = '../data/'
train_data = pd.read_csv(DATA_PATH + 'train.csv')

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
target = train_data['SalePrice']
train_data = train_data.drop(['Id','SalePrice'], axis=1)

# %% [markdown]
# ## Target analysis

# %%
target.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(10,7))
sns.distplot(target)

# %% [markdown]
# Target is skewed to the right and has some outliers above 70000

# %%
plt.figure(figsize=(10,7))
sns.distplot(np.log(target))

# %% [markdown]
# The competition uses the RMSLE (Root Mean Square Logaritic Error). Taking the log of the target then solves two problems. The skewness, aproximating it to a normal distribution, and now the RMSE can direct applied to the target and we'll get the RMSLE.

# %% [markdown]
# ## Feature analysis

# %%
train_data.describe().iloc[:,:10]
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315
# std      30.202904     20.645407   181.066207   456.098091   161.319273
# ...

# %%
train_data.describe().iloc[:,10:20]
# Out:
#          BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean    567.240411  1057.429452  1162.626712   346.992466      5.844521
# std     441.866955   438.705324   386.587738   436.528436     48.623081
# min       0.000000     0.000000   334.000000     0.000000      0.000000
# 25%     223.000000   795.750000   882.000000     0.000000      0.000000
# 50%     477.500000   991.500000  1087.000000     0.000000      0.000000
# 75%     808.000000  1298.250000  1391.250000   728.000000      0.000000
# max    2336.000000  6110.000000  4692.000000  2065.000000    572.000000
#
#          GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath     HalfBath
# count  1460.000000   1460.000000   1460.000000  1460.000000  1460.000000
# mean   1515.463699      0.425342      0.057534     1.565068     0.382877
# std     525.480383      0.518911      0.238753     0.550916     0.502885
# ...

# %%
train_data.describe().iloc[:,20:30]
# Out:
#        BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  GarageYrBlt  \
# count   1460.000000   1460.000000   1460.000000  1460.000000  1379.000000
# mean       2.866438      1.046575      6.517808     0.613014  1978.506164
# std        0.815778      0.220338      1.625393     0.644666    24.689725
# min        0.000000      0.000000      2.000000     0.000000  1900.000000
# 25%        2.000000      1.000000      5.000000     0.000000  1961.000000
# 50%        3.000000      1.000000      6.000000     1.000000  1980.000000
# 75%        3.000000      1.000000      7.000000     1.000000  2002.000000
# max        8.000000      3.000000     14.000000     3.000000  2010.000000
#
#         GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch
# count  1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean      1.767123   472.980137    94.244521    46.660274      21.954110
# std       0.747315   213.804841   125.338794    66.256028      61.119149
# ...

# %%
train_data.describe().iloc[:,30:40]
# Out:
#          3SsnPorch  ScreenPorch     PoolArea       MiscVal       MoSold  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean      3.409589    15.060959     2.758904     43.489041     6.321918
# std      29.317331    55.757415    40.177307    496.123024     2.703626
# min       0.000000     0.000000     0.000000      0.000000     1.000000
# 25%       0.000000     0.000000     0.000000      0.000000     5.000000
# 50%       0.000000     0.000000     0.000000      0.000000     6.000000
# 75%       0.000000     0.000000     0.000000      0.000000     8.000000
# max     508.000000   480.000000   738.000000  15500.000000    12.000000
#
#             YrSold
# count  1460.000000
# mean   2007.815753
# std       1.328095
# min    2006.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2010.000000

# %% [markdown]
# ## Checking missing values

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 79 columns):
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# ...

# %%
train_data.count().loc[train_data.count()<len(train_data)]/len(train_data)
# Out:
# LotFrontage     0.822603
# Alley           0.062329
# MasVnrType      0.994521
# MasVnrArea      0.994521
# BsmtQual        0.974658
# BsmtCond        0.974658
# BsmtExposure    0.973973
# BsmtFinType1    0.974658
# BsmtFinType2    0.973973
# Electrical      0.999315
# FireplaceQu     0.527397
# GarageType      0.944521
# GarageYrBlt     0.944521
# GarageFinish    0.944521
# GarageQual      0.944521
# GarageCond      0.944521
# PoolQC          0.004795
# Fence           0.192466
# MiscFeature     0.036986
# dtype: float64

# %% [markdown]
# `PoolQC`, `MiscFeature`, `Fence` and `Alley` have only a small percentage of non-null values

# %%
numerical_columns = train_data.select_dtypes(['int64','float64']).columns
categorical_columns = train_data.select_dtypes(['object']).columns
print('Numerical columns: {} \nCategorical columns: {}'.format(len(numerical_columns), len(categorical_columns)))
# Out:
# Numerical columns: 36
# Categorical columns: 43

# %% [markdown]
# ## Distribution of numerical features

# %%
fig, axes = plt.subplots(nrows=18, ncols=2, figsize=(15,100))
for i, column in enumerate(numerical_columns):
    sns.distplot(train_data[column].dropna(),ax=axes[i//2,i%2])

# %% [markdown]
# ## Correation between features and target

# %%
num_data = pd.concat([train_data[numerical_columns], target], axis=1)
corr = num_data.dropna().corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr)

# %%
hm_cols = corr.nlargest(10, 'SalePrice').index
corr = np.corrcoef(num_data[hm_cols].values.T)
plt.figure(figsize=(7,5))
sns.heatmap(corr, yticklabels=hm_cols, xticklabels=hm_cols, annot=True)

# %% [markdown]
# ## Cardinality of categorical features

# %%
high_cardinality_features = train_data[categorical_columns].nunique().loc[train_data[categorical_columns].nunique() > 10]
train_data[categorical_columns].nunique().sort_values()
# Out:
# Street            2
# Alley             2
# CentralAir        2
# Utilities         2
# LandSlope         3
# PoolQC            3
# PavedDrive        3
# GarageFinish      3
# BsmtQual          4
# ExterQual         4
# MasVnrType        4
# KitchenQual       4
# BsmtCond          4
# BsmtExposure      4
# Fence             4
# MiscFeature       4
# LandContour       4
# LotShape          4
# FireplaceQu       5
# Electrical        5
# HeatingQC         5
# GarageQual        5
# GarageCond        5
# MSZoning          5
# LotConfig         5
# BldgType          5
# ExterCond         5
# BsmtFinType1      6
# RoofStyle         6
# GarageType        6
# Foundation        6
# Heating           6
# BsmtFinType2      6
# SaleCondition     6
# Functional        7
# RoofMatl          8
# HouseStyle        8
# Condition2        8
# SaleType          9
# Condition1        9
# Exterior1st      15
# Exterior2nd      16
# Neighborhood     25
# dtype: int64

# %%
print('Features with high cardinality: ')
print(high_cardinality_features.index.tolist())
# Out:
# Features with high cardinality:
# ['Neighborhood', 'Exterior1st', 'Exterior2nd']

# %% [markdown]
# ## Imbalanced features

# %%
train_data[categorical_columns] = train_data[categorical_columns].fillna('NA')
